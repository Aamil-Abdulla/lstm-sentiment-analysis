# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %%
sent = ["I am Aamil",
        "A glass of juice",
        "I am a good devveloper",
        "I am a good Ai developer",
        "Your videos are awesome"]

# %%
voc_size=10000

# %%
ohe=[one_hot(words,vocabulary_size)for words in sent]

# %%
ohe
# Out:
# [[4856, 57, 4318],
#  [2265, 3202, 1091, 4335],
#  [4856, 57, 2265, 2698, 3837],
#  [4856, 57, 2265, 2698, 4938, 1755],
#  [266, 1602, 4629, 4933]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
#Pre padding
sent_length=8
embedded_docs=pad_sequences(ohe,padding="pre",maxlen=sent_length)

# %%
print(embedded)
from tensorflow.keras.models import Sequential
# Out:
# [[   0    0    0    0    0 4856   57 4318]
#  [   0    0    0    0 2265 3202 1091 4335]
#  [   0    0    0 4856   57 2265 2698 3837]
#  [   0    0 4856   57 2265 2698 4938 1755]
#  [   0    0    0    0  266 1602 4629 4933]]

# %%
model=Sequential()
model.add(Embedding(voc_size,output_dim=10))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)              │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)              │ (None, 8, 10)               │         100,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,    0, 4856,   57, 4318])

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# array([[[ 0.00938424, -0.01540196,  0.03585061, -0.00949339,
#          -0.03955223,  0.0059324 , -0.01547293, -0.01089768,
#          -0.03660579,  0.02634102],
#         [ 0.00938424, -0.01540196,  0.03585061, -0.00949339,
#          -0.03955223,  0.0059324 , -0.01547293, -0.01089768,
#          -0.03660579,  0.02634102],
#         [ 0.00938424, -0.01540196,  0.03585061, -0.00949339,
#          -0.03955223,  0.0059324 , -0.01547293, -0.01089768,
#          -0.03660579,  0.02634102],
#         [ 0.00938424, -0.01540196,  0.03585061, -0.00949339,
#          -0.03955223,  0.0059324 , -0.01547293, -0.01089768,
#          -0.03660579,  0.02634102],
#         [ 0.00938424, -0.01540196,  0.03585061, -0.00949339,
#          -0.03955223,  0.0059324 , -0.01547293, -0.01089768,
#          -0.03660579,  0.02634102],
#         [ 0.0432819 ,  0.01935208,  0.01393259, -0.0011016 ,
#           0.01183647,  0.04345114, -0.04890779, -0.00468178,
# ...
