# %%
sent=["The world is a better place",
      "Marvel series is my favourite movie",
      "I like DC movies",
      "the cat is eating the food",
      "Tom and Jerry is my favourite movie",
      "Python is my favourite programming language"
      ]

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Embedding
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
voc_size=10000

# %%
ohe=[one_hot(words,voc_size)for words in sent]

# %%
ohe
# Out:
# [[2219, 3480, 730, 909, 8500, 4832],
#  [9345, 6476, 730, 3142, 3489, 7733],
#  [3924, 7822, 4175, 6666],
#  [2219, 6248, 730, 8857, 2219, 539],
#  [4044, 7242, 9709, 730, 3142, 3489, 7733],
#  [1701, 730, 3142, 3489, 2687, 6643]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sent_length=9
padded_docs=pad_sequences(sequences=ohe,maxlen=sent_length,padding="pre")
padded_docs[0]
# Out:
# array([   0,    0,    0, 2219, 3480,  730,  909, 8500, 4832])

# %%
model=Sequential()
model.add(Embedding(input_dim=voc_size,output_dim=10))
model.build(input_shape=(None,sent_length))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 9, 10)               │         100,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(padded_docs[)
